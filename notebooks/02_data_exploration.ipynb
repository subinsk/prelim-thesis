# %% [markdown]
# # Docker Container Data Exploration
#
# This notebook explores the structure and size of Docker container filesystem tarballs
# used for self-supervised training.

# %% [markdown]
# ## Lightweight Benign Images
#
# Initial experiments use lightweight Docker images (Alpine, BusyBox) to
# simplify debugging and validate the preprocessing pipeline before
# scaling to larger container images.
