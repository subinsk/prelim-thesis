# %% [markdown]
# # Tarball to Byte-Image Conversion
#
# This notebook converts Docker container filesystem tarballs into
# grayscale images using raw byte-to-pixel mapping.

# %%
import os
import sys

PROJECT_ROOT = os.path.abspath("..")
if PROJECT_ROOT not in sys.path:
    sys.path.append(PROJECT_ROOT)

# %%
import os
from scripts.tar_to_image import tar_to_grayscale_image


input_tar = os.path.join(
    PROJECT_ROOT, "data", "raw", "docker_tarballs", "alpine_3_19.tar"
)

output_img = os.path.join(
    PROJECT_ROOT, "data", "processed", "images", "alpine_3_19.png"
)

os.makedirs(os.path.dirname(output_img), exist_ok=True)

tar_to_grayscale_image(input_tar, output_img, width=256)
# Out:
# Saved image to D:\projects\prelim-thesis\data\processed\images\alpine_3_19.png
# Image shape: (13428, 256)

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image

img_path = os.path.join(
    PROJECT_ROOT, "data", "processed", "images", "alpine_3_19.png"
)

print("Image exists:", os.path.exists(img_path))
print("Path:", img_path)

img = Image.open(img_path)

plt.figure(figsize=(4, 8))
plt.imshow(img, cmap="gray")
plt.axis("off")
plt.title("Alpine Container Byte Image")
plt.show()
# Out:
# Image exists: True
# Path: D:\projects\prelim-thesis\data\processed\images\alpine_3_19.png

# %%
input_tar = os.path.join(
    PROJECT_ROOT, "data", "raw", "docker_tarballs", "busybox.tar"
)

output_img = os.path.join(
    PROJECT_ROOT, "data", "processed", "images", "busybox.png"
)

tar_to_grayscale_image(input_tar, output_img, width=256)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 tar_to_grayscale_image(
#       2     "data/raw/docker_tarballs/busybox.tar",
#       3     "data/processed/images/busybox.png",
#       4     width=256
#       5 )
#
# File D:\projects\prelim-thesis\scripts\tar_to_image.py:7, in tar_to_grayscale_image(tar_path, output_path, width)
#       5 def tar_to_grayscale_image(tar_path, output_path, width=256):
#       6     # Read tar file as raw bytes
# ----> 7     with open(tar_path, "rb") as f:
#       8         byte_data = f.read()
#      10     # Convert bytes to numpy array (0–255)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/raw/docker_tarballs/busybox.tar'

# %% [markdown]
# ## Observations
#
# - Byte-level images show clear structural patterns rather than random noise.
# - Lightweight images such as Alpine and BusyBox produce visually distinct patterns.
# - This suggests that container filesystem structure is captured by the representation.
